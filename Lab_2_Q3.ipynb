# %% [markdown]
# <a href="https://colab.research.google.com/github/ranvirdkr/CSCI-A-310/blob/main/Lab_2_Q3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def get_matching_event(event_condition, sample_space):
  return set([outcome for outcome in sample_space if event_condition(outcome)])

def compute_event_probability(event_condition, generic_sample_space):
  event=get_matching_event(event_condition,generic_sample_space)
  if type(generic_sample_space) == type(set()):
    return len(event)/len(generic_sample_space)
  event_size = sum(generic_sample_space[outcome] for outcome in event)
  return event_size/sum(generic_sample_space.values())

# %%
possible_rolls=list(range(1,7))
print(possible_rolls)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
from itertools import product
sample_space = set(product(possible_rolls,repeat=8))

len(sample_space)
# Out:
# 1679616

# %%
def has_sum_of_28(outcome): return sum(outcome) == 28

prob = compute_event_probability(has_sum_of_28,sample_space)
print(f"8 rolls sum to 28  with probability of {prob}")
# Out:
# 8 rolls sum to 28  with probability of 0.08094350137174211
